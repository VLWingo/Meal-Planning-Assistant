# %% [markdown]
# Let's demonstrate this program.
#
# First, we will use its "Generate week" feature. This creates a random list of meals to prepare for a given number of days. We will use 7 days, 2 days being weekends.
# Why do weekends matter? More time to cook, so we can allow for 2 difficult recipes.
#
# The program will randomly determine the distributions of "meat types", such as pork or vegetarian, for the week. It then must randomly select meals from the recipes dictionary.
#
# Sometimes, the program takes a while to spit out a result. It generates and throws away many potential lists. The program tailors the results to a few user preferences, such as how many recipes can be made from beef or how often you want to eat potato soup.
#
# We're on a little bit of a budget and aren't interested in trying something new this week, so let's replace the 'Black Pepper Beef with Asparagus' recipe. We'll let the program choose something new for us.
#
# Looks like it worked out this time, but if we didn't like the results, we could choose to replace the recipe with one we already know.
#
# With that taken care of, let's look at the grocery list. We already have enough Onion Powder at home, so we can remove it.
#
# Milk's already on the list, do we have enough cereal for the week? Let's add it to the list.
#
# Oops! Seems we typed a little fast and made a mistake. The program saves us the trouble of adding the error to the list.
#
# Let's look at what we're having this week one more time before saving our results and exiting the program.
#
# When the next week comes around, we have other options, such as building a list around recipes we've already decided on, or producing the grocery list for a list of dinners we already have.

# %%
import Master_Program
# Out:
# Last 4 Entries:           Date  Days                                            Recipes
# 0  2021-07-26     5  [Sausages, Chicken with Pasta-Roni, Chicken Ma...
# 1  2021-07-27     7  [Pizza, Haluski Noodles, Kielbasa with Cabbage...
# 2  2021-08-07     7  [Pizza, Steak, Kielbasa with Cabbage and Piero...
# 3  2021-08-21     6  [Roasted Beef Tips, Zuppa Toscana, Chicken Wil...
# Select option:
#                     1 - Generate week
#                     2 - Build week around list
#                     3 - Generate grocery list from list
#                     4 - Exit program  1
# How many days are being planned:  7
# How many days are weekends:  2
#                                     Difficulty     Meat  \
# Burgers                                      0     beef
# Black Pepper Beef with Asparagus             0     beef
# Kielbasa with Cabbage and Pierogis           0     pork
# Pasta-Roni Chicken                           0  chicken
# ...
